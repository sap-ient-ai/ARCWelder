# %%
from ARC import ARC

def p(k):
    train, _ = ARC.load(k)
    print(train[0])
# Out:
# `setup_ipynb.py` executed, (multi-output enabled for subsequent cell executions).

# %%
done = [1, 8, 26, 33, 57, 174, 179, 313, 318, 323]
notable = [45, 65, 106, 118, 162, 167, 184, 242, 285, ]

for k in notable:
    print(k)
    p(k)
    print()
# Out:
# 45
# [
# ⚫ 🟣 ⚫ ⚫ ⚫ ⚫ ⚫ ⚫ ⚫
# 🔵 🔵 ⚫ 🟣 ⚪ ⚫ 🟣 🔵 🔵
# ⚫ ⚫ ⚫ ⚫ 🟣 ⚫ ⚫ ⚫ ⚫
# ,
# ⚫ 🔵 ⚪ ⚪ ⚫ ⚫ ⚫
# 🔵 🔵 ⚫ ⚪ 🔵 🔵 🔵
# ⚫ ⚫ ⚫ ⚫ ⚫ ⚫ ⚫
# ]
#
# 65
# [
# ⚫ ⚫ ⚫ ⚫ 🔴 🔴 🔴 🔴 🔴 ⚫ ⚫ 🔴 ⚫ 🔴 🔴 🔴 ⚫ 🔴 ⚫ 🔴
# ⚫ 🔴 ⚫ ⚫ ⚫ ⚫ ⚫ 🔴 ⚫ ⚫ ⚫ ⚫ ⚫ 🔴 ⚫ 🔴 ⚫ ⚫ ⚫ ⚫
# 🔴 🔴 🔴 🔴 🔴 ⚫ 🔴 ⚫ 🔴 ⚫ ⚫ ⚫ 🔴 🔴 🔴 ⚫ ⚫ 🔵 ⚫ ⚫
# 🔴 ⚫ 🔴 🔴 ⚫ ⚫ ⚫ ⚫ ⚫ ⚫ 🔴 🔴 🔴 🔴 🔴 🔴 ⚫ 🔵 ⚫ ⚫
# 🔴 ⚫ ⚫ 🔴 🔴 ⚫ ⚫ ⚫ ⚫ ⚫ ⚫ 🔴 ⚫ 🔴 ⚫ ⚫ ⚫ ⚫ ⚫ ⚫
# ⚫ ⚫ ⚫ 🔴 ⚫ ⚫ ⚫ ⚫ ⚫ ⚫ ⚫ ⚫ ⚫ 🔴 ⚫ ⚫ ⚫ ⚫ ⚫ ⚫
# 🔴 ⚫ ⚫ ⚫ ⚫ ⚫ ⚫ ⚫ ⚫ ⚫ ⚫ ⚫ ⚫ ⚫ ⚫ ⚫ ⚫ ⚫ 🔴 ⚫
# ⚫ ⚫ 🔴 ⚫ ⚫ ⚫ ⚫ ⚫ ⚫ ⚫ ⚫ ⚫ ⚫ ⚫ ⚫ ⚫ ⚫ ⚫ 🔴 🔴
# 🔴 ⚫ ⚫ ⚫ ⚫ ⚫ ⚫ ⚫ ⚫ ⚫ ⚫ ⚫ 🔴 ⚫ ⚫ ⚫ ⚫ ⚫ 🔴 🔴
# ⚫ ⚫ ⚫ ⚫ ⚫ ⚫ ⚫ ⚫ ⚫ 🔴 ⚫ ⚫ 🔴 ⚫ ⚫ ⚫ ⚫ ⚫ 🔴 🔴
# ⚫ 🔴 ⚫ ⚫ ⚫ ⚫ 🔴 🔴 🔴 ⚫ 🔴 ⚫ ⚫ 🔴 ⚫ 🔴 🔴 ⚫ ⚫ ⚫
# 🔴 ⚫ ⚫ ⚫ ⚫ 🔴 ⚫ ⚫ ⚫ ⚫ 🔴 🔴 🔴 🔴 🔴 🔴 🔴 🔴 🔴 🔴
# ⚫ ⚫ ⚫ ⚫ ⚫ ⚫ 🔴 🔴 🔴 ⚫ ⚫ 🔴 🔴 🔴 ⚫ 🔴 ⚫ ⚫ 🔴 🔴
# ⚫ ⚫ ⚫ ⚫ ⚫ ⚫ 🔴 🔴 ⚫ ⚫ ⚫ ⚫ 🔴 ⚫ ⚫ ⚫ 🔴 ⚫ ⚫ 🔴
# ⚫ ⚫ ⚫ 🟢 ⚫ ⚫ ⚫ 🔴 ⚫ 🔴 ⚫ 🔴 ⚫ ⚫ 🔴 ⚫ ⚫ 🔴 ⚫ 🔴
# ⚫ ⚫ ⚫ 🟢 ⚫ ⚫ 🔴 🔴 🔴 ⚫ ⚫ ⚫ 🔴 🔴 🔴 🔴 ⚫ ⚫ ⚫ ⚫
# ⚫ 🔴 ⚫ ⚫ ⚫ ⚫ ⚫ 🔴 ⚫ 🔴 🔴 ⚫ 🔴 ⚫ 🔴 ⚫ 🔴 ⚫ ⚫ ⚫
# ⚫ ⚫ ⚫ ⚫ ⚫ ⚫ ⚫ 🔴 ⚫ ⚫ ⚫ 🔴 ⚫ ⚫ ⚫ ⚫ ⚫ 🔴 🔴 ⚫
# ⚫ ⚫ ⚫ 🔴 ⚫ ⚫ ⚫ 🔴 ⚫ 🔴 ⚫ ⚫ 🔴 🔴 🔴 ⚫ ⚫ ⚫ ⚫ 🔴
# ⚫ ⚫ ⚫ ⚫ 🔴 🔴 🔴 🔴 ⚫ ⚫ 🔴 ⚫ ⚫ ⚫ ⚫ 🔴 🔴 🔴 ⚫ ⚫
# ,
# ...
